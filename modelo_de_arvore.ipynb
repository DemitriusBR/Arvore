# %% [markdown]
# <a href="https://colab.research.google.com/github/DemitriusBR/Arvore/blob/main/modelo_de_arvore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("vendas.xlsx")
df.head()
# Out:
#    media_rating  media_pedidos test cliente_comprou
# 0           1.5             11   No             Yes
# 1           2.5             11   No              No
# 2           2.5             11   No              No
# 3           1.5             13   No             Yes
# 4           2.5             13   No              No

# %%
x = df[["media_rating","media_pedidos","test"]]
y = df["cliente_comprou"]
x
# Out:
#     media_rating  media_pedidos test
# 0            1.5             11   No
# 1            2.5             11   No
# 2            2.5             11   No
# 3            1.5             13   No
# 4            2.5             13   No
# 5            2.5             13   No
# 6            1.5             15   No
# 7            2.5             15   No
# 8            2.5             15   No
# 9            1.5             27   No
# 10           2.5             27   No
# 11           2.5             27   No
# 12           1.5             39   No
# 13           2.5             39   No
# 14           2.5             39   No
# 15           3.5             11  Yes
# 16           3.5             11  Yes
# 17           4.5             11  Yes
# 18           3.5             13  Yes
# 19           3.5             13  Yes
# 20           4.5             13  Yes
# 21           3.5             15  Yes
# 22           3.5             15  Yes
# 23           4.5             15  Yes
# ...

# %%
x = pd.get_dummies(x)

# %%
from sklearn import tree

# %%
arvore = tree.DecisionTreeClassifier()
modelo = arvore.fit(x,y)

# %%
modelo
# Out:
# DecisionTreeClassifier()

# %%
fig = plt.figure(figsize=(40,30))
tree = tree.plot_tree(modelo, feature_names=x.columns,class_names = ["Yes","No"], filled = True)
